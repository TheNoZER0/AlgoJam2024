# %% [markdown]
# Inital attempt:
# (Just buy low, sell high)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To try see if EMA works better, I stole Gabe's code from Jeans and made it work here.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Sadly, it didn't really work, but fiddling with the span parameter might work. With a span of 10 instead of 4:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# So that didn't really work any better either.

# %% [markdown]
# Trying with a span of 3:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Overall, EMA almost makes half of what the simple strategy does, so isn't worth pursuing.

# %% [markdown]
# So back to the original strategy of buy low, sell high, but also try to get a little extra money at the start and end.
# - This means that before day 40 and after day 330 we'll try to trade a little

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We now have Total PNL ($): 126400.00, which is 14000.00 more
