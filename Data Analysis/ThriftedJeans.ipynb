# %%
import math
import pandas as pd

# Load Thrifted Jeans data
jeans = pd.read_csv('/Users/jameshurst/Library/CloudStorage/SynologyDrive-james/Dropbox/Quant/AlgoJam2024/data/Thrifted Jeans_price_history.csv')
jeans = jeans.loc[:, 'Day':'Unnamed: 2']
jeans
# Out:
#      Day  Price  Unnamed: 2
# 0      0  40.00        0.00
# 1      1  53.03       13.03
# 2      2  48.09        8.09
# 3      3  50.24       10.24
# 4      4  50.83       10.83
# ..   ...    ...         ...
# 360  360  71.27       31.27
# 361  361  74.61       34.61
# 362  362  63.90       23.90
# 363  363  75.64       35.64
# 364  364  68.61       28.61
#
# [365 rows x 3 columns]

# %%
# plot x-axis = day, y-axis = price from dataframe
import matplotlib.pyplot as plt
plt.plot(jeans['Day'], jeans['Price'])

# %%
jeans.rename(columns={'Unnamed: 2': 'Difference'}, inplace=True)
# plt.plot(jeans['Day'], jeans['Price'])
# plt.plot(jeans['Day'], jeans['Price2'])
jeans
# Out:
#      Day  Price  Difference
# 0      0  40.00        0.00
# 1      1  53.03       13.03
# 2      2  48.09        8.09
# 3      3  50.24       10.24
# 4      4  50.83       10.83
# ..   ...    ...         ...
# 360  360  71.27       31.27
# 361  361  74.61       34.61
# 362  362  63.90       23.90
# 363  363  75.64       35.64
# 364  364  68.61       28.61
#
# [365 rows x 3 columns]

# %%
plt.plot(jeans['Day'], jeans['Price'])

# %%
# create another column that is the exponential moving average of the price
jeans['EMA15'] = jeans['Price'].ewm(span=15, adjust=False).mean()
jeans['EMA5'] = jeans['Price'].ewm(span=5, adjust=False).mean()
plot_column = jeans['EMA5']
# plot EMA5
plt.plot(jeans['Day'], jeans['Price'])
plt.plot(jeans['Day'], plot_column)
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
plt.plot(jeans['Day'], jeans['Price'])
plt.plot(jeans['Day'], plot_column)
plt.xlim(100, 200)
# Out:
# (100.0, 200.0)

# %%
plt.plot(jeans['Day'], jeans['Price'])
plt.plot(jeans['Day'], plot_column)
plt.xlim(200, 300)
# Out:
# (200.0, 300.0)

# %%
plt.plot(jeans['Day'], jeans['Price'])
plt.plot(jeans['Day'], plot_column)
plt.xlim(200, 366)
# Out:
# (200.0, 366.0)

# %%
# Out:
#      Day  Price  Difference      EMA15       EMA5
# 0      0  40.00        0.00  40.000000  40.000000
# 1      1  53.03       13.03  41.628750  44.343333
# 2      2  48.09        8.09  42.436406  45.592222
# 3      3  50.24       10.24  43.411855  47.141481
# 4      4  50.83       10.83  44.339124  48.370988
# ..   ...    ...         ...        ...        ...
# 360  360  71.27       31.27  69.073701  68.610225
# 361  361  74.61       34.61  69.765738  70.610150
# 362  362  63.90       23.90  69.032521  68.373433
# 363  363  75.64       35.64  69.858456  70.795622
# 364  364  68.61       28.61  69.702399  70.067082
#
# [365 rows x 5 columns]
