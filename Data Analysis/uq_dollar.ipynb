# %% [markdown]
# Trading at the long/short limits:

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# Tested using the difference between the current value and the mean:
# ![image.png](attachment:image.png)

# %% [markdown]
# Trying to use an exponential:
# ![image.png](attachment:image.png)

# %% [markdown]
# Test increasing the factor in the exponent from 2 to 3:
# ![image.png](attachment:image.png)

# %% [markdown]
# Try to max out the exponent, and it made more money!
# ![image.png](attachment:image.png)

# %% [markdown]
# Then tested with just trading at the limits at every possible time, and it gave the same amount as above, becasue they're essentially the same.

# %% [markdown]
# Now test changing the boundaries for when we trade:
#
# - 0.3:    Total PNL ($): 89687.00
# - 0.27:   Total PNL ($): 95329.00
# - 0.25:   Total PNL ($): 100321.00
# - 0.24:   Total PNL ($): 100698.00
# - 0.23:   Total PNL ($): 100451.00
# - 0.22:   Total PNL ($): 99658.00
# - 0.2:    Total PNL ($): 99476.00
# - 0.15:   Total PNL ($): 96954.00
# - 0.1:    Total PNL ($): 91975.00
#
# Therefore, we use +-0.24 for the bounds
#
# ![image.png](attachment:image.png)
