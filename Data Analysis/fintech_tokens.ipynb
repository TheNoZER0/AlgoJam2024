# %% [markdown]
# Initial attempt of buying when our real price is lower than our estimated price:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# This did NOT work and needs to be fixed. Probably needs a bit more finesse in the approach

# %% [markdown]
# So I tried comparing the gradient of a line through the points of the last 5 days to that of the 5 days before them to figure out where we were on the chart. Then step up or down our position based on that. Didn't go so well (Total PNL ($): -9038.75)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **UPDATE**
# All of this was wrong because I was accidentally calling the red pen function rather than the token one. Whoops!
#
# Updated version with the actual thing from this point:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# I then found out my gradients were wrong, becasue I had it between 0 and 1, but they were much larger. This is with a bound of 15:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Sweeping the values of the bound:
#
# - lim = 10:     Total PNL ($): 9888.05
# - lim = 15:     Total PNL ($): 12661.80
# - lim = 17:     Total PNL ($): 15688.65
# - lim = 17.5:   Total PNL ($): 15688.65
# - lim = 18:     Total PNL ($): 16819.80
# - lim = 19:     Total PNL ($): 13293.40
# - lim = 20:     Total PNL ($): 12996.00
# - lim = 20.5:   Total PNL ($): 11402.25
# - lim = 22:     Total PNL ($): 9694.80
# - lim = 25:     Total PNL ($): 8312.25
#
# Therefore, we use the limit of 18 adn get:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now try just buying to the limit every time rather than stepping up:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# And now just try redoing this sweep:
#
# - lim = 15:     Total PNL ($): 37940.35
# - lim = 17:     Total PNL ($): 40784.45
# - lim = 18:     Total PNL ($): 42579.95
# - lim = 19:     Total PNL ($): 34586.65
# - lim = 20:     Total PNL ($): 34586.65
#
# So I chose to have 18 as my bound, giving this:
# ![image.png](attachment:image.png)
